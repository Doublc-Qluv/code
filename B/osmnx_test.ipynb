# %%
import osmnx as ox
# %matplotlib inline

# %%
place='西安市,中国'

# %%
city = ox.gdf_from_place(place)
print(city)
ox.plot_shape(ox.project_gdf(city))
# Out:
#     bbox_east  bbox_north  bbox_south   bbox_west  \
# 0  109.096589   34.506842   34.186842  108.776589
#
#                          geometry  \
# 0  POINT (108.9365887 34.3468421)
#
#                                           place_name
# 0  Xi'an, Weiyang District, Xi'an, Shaanxi, 71001...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-8b1f6d70d05c> in <module>
#       1 city = ox.gdf_from_place(place)
#       2 print(city)
# ----> 3 ox.plot_shape(ox.project_gdf(city))
#
# /anaconda3/envs/dl/lib/python3.6/site-packages/osmnx/plot.py in plot_shape(gdf, fc, ec, linewidth, alpha, figsize, margin, axis_off)
#      81                 ax.add_patch(patch)
#      82         else:
# ---> 83             raise ValueError('All geometries in GeoDataFrame must be shapely Polygons or MultiPolygons')
#      84
# ...

# %%
ox.plot_graph(ox.graph_from_place("西安电子科技大学长安校区",network_type = 'drive',which_result = 2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/dl/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'geometry'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-55ef4d8dabe0> in <module>
# ...

# %%
G = ox.graph_from_place('Beijing, China', which_result=2, network_type='drive')
G_proj = ox.project_graph(G)
fig, ax = ox.plot_graph(G_proj)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ee8011524082> in <module>
# ----> 1 G = ox.graph_from_place('Beijing, China', which_result=2, network_type='drive')
#       2 G_proj = ox.project_graph(G)
#       3 fig, ax = ox.plot_graph(G_proj)
#
# /anaconda3/envs/dl/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure, custom_filter)
#    1876                            max_query_area_size=max_query_area_size,
#    1877                            clean_periphery=clean_periphery, infrastructure=infrastructure,
# -> 1878                            custom_filter=custom_filter)
#    1879
# ...

# %%
34.12530175,108.829109638852
# Out:
# (34.12530175, 108.829109638852)

# %%
import osmnx as ox
ox.plot_graph(ox.graph_from_place('Modena, Italy'))
# Out:
# (<Figure size 599.212x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1a2948cda0>)

# %%
import osmnx as ox
city = ox.gdf_from_place('Berkeley, California')
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1a33d431d0>)

# %%
place1 = ox.gdf_from_place('Manhattan, New York City, New York, USA')
place2 = ox.gdf_from_place('Cook County, Illinois')
place3 = ox.gdf_from_place('Iowa, USA')
place4 = ox.gdf_from_place('Bolivia')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/envs/dl/lib/python3.6/site-packages/urllib3/response.py in _error_catcher(self)
#     359             try:
# --> 360                 yield
#     361
#
# /anaconda3/envs/dl/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     668                     break
# --> 669                 chunk = self._handle_chunk(amt)
#     670                 decoded = self._decode(chunk, decode_content=decode_content,
#
# /anaconda3/envs/dl/lib/python3.6/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     623         else:  # amt > self.chunk_left
# --> 624             returned_chunk = self._fp._safe_read(self.chunk_left)
#     625             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#
# ...

# %%
places = ox.gdf_from_places(['Botswana', 'Zambia', 'Zimbabwe'])
places = ox.project_gdf(places)
ox.save_gdf_shapefile(places)
ox.plot_shape(ox.project_gdf(places))

# %%
34.12530175,108.829109638852

# %%
G = ox.graph_from_bbox(34.12, 34.13, 108.82, 108.83, network_type='drive')

G_projected = ox.project_graph(G)
ox.plot_graph(G_projected)
# Out:
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-12-c2e3359f8b17> in <module>
# ----> 1 G = ox.graph_from_bbox(34.12, 34.13, 108.82, 108.83, network_type='drive')
#       2
#       3 G_projected = ox.project_graph(G)
#       4 ox.plot_graph(G_projected)
#
# /anaconda3/envs/dl/lib/python3.6/site-packages/osmnx/core.py in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure, custom_filter)
#    1491         # truncate graph by desired bbox to return the graph within the bbox
#    1492         # caller wants
# -> 1493         G = truncate_graph_bbox(G_buffered, north, south, east, west, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1494
#    1495         # count how many street segments in buffered graph emanate from each
#
# ...

# %%
import osmnx as ox
# %matplotlib inline

G = ox.graph_from_place('Beijing, China', which_result=2, network_type='drive')
G_proj = ox.project_graph(G)
fig, ax = ox.plot_graph(G_proj)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/envs/dl/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /anaconda3/envs/dl/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda3/envs/dl/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ...
