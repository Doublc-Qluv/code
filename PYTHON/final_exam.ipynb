# %% [markdown]
# Lending Club(www.lendingclub.com)是美国的一个P2P平台。它把需要钱的人（借钱者）和 有钱的人（投资者）联系在一起。我们试图创建一个模型来预测贷款给某人的风险，给定各种与信用相关的数据。我们将使用2007-2010年的借贷数据并试图分类和预测**某位借款人是否全额偿还贷款。**
#
# 下面是该数据集中包含的所有列：
#
# * **credit.policy**: 1 如果客户符合LendingClub.com的信用承保标准，否则 0。
# * **purpose**: 借款目的（取值"credit_card", "debt_consolidation", "educational", "major_purchase", "small_business", and "all_other"）。
# * **int.rate**: 借款利率。被LendingClub.com判断为更大风险的借款人将被赋以更高的利率。
# * **installment**: 如果是有固定利息的长期借款，借款人每月摊付的款项。
# * **log.annual.inc**: 借款人自己申报的年收入的自然对数。
# * **dti**: 借款人的负债与收入比率（负债除以年收入）。
# * **fico**: 对借款人的FICO信用评分。
# * **days.with.cr.line**: 借款人拥有信贷额度的天数。
# * **revol.bal**: 借款人的循环余额（信用卡结算周期结束时未支付的金额）。
# * **revol.util**: 借款人的循环线利用率（与可用信贷总额相对应的信贷额度）。
# * **inq.last.6mths**: 借款人过去6个月被债权人查询次数。
# * **delinq.2yrs**:在过去2年中，借款人逾期付款30天以上的次数。
# * **pub.rec**: 借款人的贬损公共记录的数量（破产申请、税务留置权或判决）。
# * **not.fully.paid**: 分类值---借款人是否全额偿还了这笔钱。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Step 1: 读取数据集 loan_data.csv，并查看前5条数据

# %%
# 请在此处填入你的代码
df=pd.read_csv('loan_data.csv',encoding='utf-8')
print(df[:5])
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# ## Step 2: 统计not.fully.paid列各种取值的个数

# %%
# 请在此处填入你的代码
zero_col_count = dict(df['not.fully.paid'].value_counts())
print(zero_col_count)
# Out:
# {0: 8045, 1: 1533}

# %% [markdown]
# ## Step 3: 分别绘制在not.fully.paid=1和not.fully.paid=0两种情况下的fico与int.rate的散点关系图（x轴为fico, y轴为int.rate）；要求把x轴标为“FICO”，把y轴标为“interest rate”，并标上相应的标题（not.fully.paid=1的图标题设为"not fully paid"，not.fully.paid=0的图标题设为"fully paid"）。

# %%
# 请在此处填入你的代码
x = df['fico']
y = df['int.rate']
for i in df[header]:
    if df['not.fully.paid'][i] == 1:
        plt.scatter(x,y)
        plt.axis()
        plt.title("not fully paid")
        plt.xlabel("FICO")
        plt.ylabel("interest rate")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7d9d8c6910ab> in <module>()
#       2 x = df['fico']
#       3 y = df['int.rate']
# ----> 4 for i in df[header]:
#       5     if df['not.fully.paid'][i] == 1:
#       6         plt.scatter(x,y)
#
# NameError: name 'header' is not defined

# %%
# 请在此处填入你的代码
x = df['fico']
y = df['int.rate']
for i in df['not.fully.paid']:
    if i == 0:
        plt.scatter(x,y)
        plt.axis()
        plt.title("not fully paid")
        plt.xlabel("FICO")
        plt.ylabel("interest rate")
plt.show()

# %% [markdown]
# ## Step 4: 查看每列缺失值的个数；如果有缺失值，补齐或者删除缺失值

# %%
# 请在此处填入你的代码
countnull = df.shape[0] - df.count()
print(countnull)
isNA=df.isnull()
df[isNA.any(axis=1)]#删除
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64
# Empty DataFrame
# Columns: [credit.policy, purpose, int.rate, installment, log.annual.inc, dti, fico, days.with.cr.line, revol.bal, revol.util, inq.last.6mths, delinq.2yrs, pub.rec, not.fully.paid]
# Index: []

# %% [markdown]
# ## Step 5: 使用Pandas中的get_dummies对purpose列进行独热编码

# %%
# 请在此处填入你的代码
pd.get_dummies(df)
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# 5                 1    0.0788       125.13       11.904968  16.98   727
# 6                 1    0.1496       194.02       10.714418   4.00   667
# 7                 1    0.1114       131.22       11.002100  11.08   722
# 8                 1    0.1134        87.19       11.407565  17.25   682
# 9                 1    0.1221        84.12       10.203592  10.00   707
# 10                1    0.1347       360.43       10.434116  22.09   677
# 11                1    0.1324       253.58       11.835009   9.16   662
# ...

# %% [markdown]
# ## Step 6: 选取“installment”、“log.annual.inc”、“dti”和“fico"四个特征来预测借款利率“int.rate”，先生成X和y，再划分训练集和测试集（其中30%用作测试）

# %%
# 请在此处填入你的代码
feature_cols = ['installment','log.annual.inc','dti','fico']
X = df[feature_cols]
X = df['int.rate']


def moveImg(path,new_path):
    img=Image.open(path)
    img.save(os.path.join(new_path,os.path.basename(path)))
#30%的数据生成验证集
new_path='G:/data_image/val/'
i=0
while(i <= (int(n*0.3))):
    DatasetPath = url + classname + str(array[i]) + '.jpg' 
    moveImg(DatasetPath,new_path)
    i=i+1
#70%的数据生成训练集
new_path='G:/data_image/train/'
while(i <= (n-1)):
    DatasetPath = url + classname + str(array[i]) + '.jpg'
    moveImg(DatasetPath,new_path)
    i=i+1   
--------------------- 
作者：@阳@ 
来源：CSDN 
原文：https://blog.csdn.net/weixin_41319671/article/details/82662454 
版权声明：本文为博主原创文章，转载请附上博文链接！
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1c105343bcce> in <module>()
#       3 X = df[feature_cols]
#       4 X = df['int.rate']
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#       6 print(X_train.shape)
#       7 print(y_train.shape)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# ## Step 7: 训练一个带L2正则项的线性回归器（Ridge）来预测借款利率，然后在测试集上进行预测，并显示预测结果的均方根误差（RMSE）

# %%
# 请在此处填入你的代码

# %% [markdown]
# ## Step 8: 使用除“not.fully.paid"之外的所有列作为特征列来预测“not.fully.paid”，先生成X和y，再划分训练集和测试集（其中3000个样例用作测试）

# %%
# 请在此处填入你的代码

# %% [markdown]
# ## Step 9：使用随机森林模型拟合上一步生成的训练数据，要求采用GridSearchCV来自动调节随机森林中决策树的个数（尝试范围为[10，50，100，200]）和最大特征数（尝试范围为1到所有特征数），最后显示GridSearch得到的最佳参数值

# %%
# 请在此处填入你的代码

# %% [markdown]
# ## Step 10: 使用GridSearchCV得到的最佳模型对测试数据进行预测，并调用classification_report显示评估结果

# %%
# 请在此处填入你的代码
